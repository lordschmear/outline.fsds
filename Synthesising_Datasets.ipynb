# %% [markdown]
# # Synthesising Datasets
# In this notebook, we combine the **cleaned** datasets that came from other analysis. Geometry needs to be added back into the datasets.
#
# * Inside Airbnb Datasets
# * LSOA & Deprivation
# * Evictions

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib as mpl
import re
import math

from matplotlib.colors import ListedColormap

# All of these are potentially useful, though
# not all have been used in this practical --
# I'd suggest exploring the use of different 
# Scalers/Transformers as well as clustering 
# algorithms...
import sklearn
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, PowerTransformer
from sklearn.cluster import KMeans, DBSCAN, OPTICS
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import random
random.seed(42)    # For reproducibility
np.random.seed(42) # For reproducibility

# Make numeric display a bit neater
pd.set_option('display.float_format', lambda x: '{:,.2f}'.format(x))
# Out:
# <jemalloc>: MADV_DONTNEED does not work (memset will be used instead)
# <jemalloc>: (This is the expected behaviour if you are running under QEMU)

# %%
# This is the Cache Function Jon wrote
import os
from requests import get
from urllib.parse import urlparse

def cache_data(src:str, dest:str) -> str:
    """Downloads and caches a remote file locally.
    
    The function sits between the 'read' step of a pandas or geopandas
    data frame and downloading the file from a remote location. The idea
    is that it will save it locally so that you don't need to remember to
    do so yourself. Subsequent re-reads of the file will return instantly
    rather than downloading the entire file for a second or n-th itme.
    
    Parameters
    ----------
    src : str
        The remote *source* for the file, any valid URL should work.
    dest : str
        The *destination* location to save the downloaded file.
        
    Returns
    -------
    str
        A string representing the local location of the file.
    """
    
    url = urlparse(src) # We assume that this is some kind of valid URL 
    fn  = os.path.split(url.path)[-1] # Extract the filename
    dfn = os.path.join(dest,fn) # Destination filename
    
    # Check if dest+filename does *not* exist -- 
    # that would mean we have to download it!
    if not os.path.isfile(dfn) or os.path.getsize(dfn) < 1:
        
        print(f"{dfn} not found, downloading!")

        # Convert the path back into a list (without)
        # the filename -- we need to check that directories
        # exist first.
        path = os.path.split(dest)
        
        # Create any missing directories in dest(ination) path
        # -- os.path.join is the reverse of split (as you saw above)
        # but it doesn't work with lists... so I had to google how
        # to use the 'splat' operator! os.makedirs creates missing
        # directories in a path automatically.
        if len(path) >= 1 and path[0] != '':
            os.makedirs(os.path.join(*path), exist_ok=True)
            
        # Download and write the file
        with open(dfn, "wb") as file:
            response = get(src)
            file.write(response.content)
            
        print('Done downloading...')

    else:
        print(f"Found {dfn} locally!")

    return dfn

# %%
# adding the borough data for maps
ddir  = os.path.join('data','geo') # destination directory
spath = 'https://github.com/jreades/fsds/blob/master/data/src/' # source path

boros = gpd.read_file( cache_data(spath+'Boroughs.gpkg?raw=true', ddir) )
water = gpd.read_file( cache_data(spath+'Water.gpkg?raw=true', ddir) )
green = gpd.read_file( cache_data(spath+'Greenspace.gpkg?raw=true', ddir) )

print('Done.')
# Out:
# Found data/geo/Boroughs.gpkg locally!
# Found data/geo/Water.gpkg locally!
# Found data/geo/Greenspace.gpkg locally!
# Done.

# %% [markdown]
# Here,

# %%
lsoa_shp_file = gpd.read_file('LSOA & Dep Data/ESRI/LSOA_2011_London_gen_MHW.shp')

# %% [markdown]
# #### Read in 2022 Airbnb Data

# %%
#Note, this does not include the geometry because that is not preserved when something is read as a feather. Further, this only includes the fields we are interested in. For the cleaned dataset with all of the fields clean, go to the Airbnb2022_Final.ipynb
listings2022 = pd.read_feather('listings22')

# %% [markdown]
# <u>The following Datasets have been Filtered by Terms associated with Gentrification<u>

# %%
listings2022_gentrification = pd.read_feather('listings22_gentrification')

# %%
listings2022_kensington_chelsea = pd.read_feather('listings22_kensington_chelsea')

# %%
listings2022_camden = pd.read_feather('listings22_camden')

# %%
listings2022_hackney = pd.read_feather('listings22_hackney')

# %% [markdown]
# #### Read in 2019 Airbnb Data

# %% [markdown]
# #### Read in Eviction Data

# %%
evict2019 = pd.read_csv('2019_evictions_geom')

# %%
evict2022 = pd.read_csv('2022_evictions_geom')

# %% [markdown]
# #### Read in LSOA & IMD Data
# This data is for each borough that we are targetting but broken down into LSOAs so we can get a more micro level view of deprivation there.

# %%
hackney_dep = pd.read_csv('LSOA & Dep Data/hackLSOA_dep')

# %%
camden_dep = pd.read_csv('LSOA & Dep Data/CamdenLSOA_dep')

# %%
kc_dep = pd.read_csv('LSOA & Dep Data/kcLSOA_dep')

# %%
London_dep = pd.read_csv('LSOA & Dep Data/London_dep')

# %%
London_dep.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'LSOA11CD',
#  'LSOA11NM',
#  'geometry',
#  'LSOA code (2011)',
#  'Local Authority District code (2019)',
#  'LAD',
#  'Barriers to Housing and Services Score',
#  'Barriers to Housing and Services Rank (where 1 is most deprived)',
#  'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)',
#  'transformed_mms']

# %%
London_borough_dep = London_dep.groupby('LAD')['Barriers to Housing and Services Score'].agg('mean')

# %%
London_borough_dep.info(verbose=True)
# Out:
# <class 'pandas.core.series.Series'>
# Index: 33 entries, Barking and Dagenham to Westminster
# Series name: Barriers to Housing and Services Score
# Non-Null Count  Dtype
# --------------  -----
# 33 non-null     float64
# dtypes: float64(1)
# memory usage: 528.0+ bytes

# %% [markdown]
# ### Merging 2022 Airbnb Data: All London

# %%
airbnb_merged1 = pd.merge(listings2022, evict2022, how="inner", left_on='neighbourhood_cleansed', 
                          right_on='Area', suffixes=('neighbourhood_cleansed', 'Area'))

# %%
airbnb_merged2 = pd.merge(airbnb_merged1, London_borough_dep, how="inner", left_on='neighbourhood_cleansed', 
                          right_on='LAD', suffixes=('neighbourhood_cleansed', 'Area'))

# %%
airbnb_merged2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69054 entries, 0 to 69053
# Data columns (total 29 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      69054 non-null  int64
#  1   name                                    69034 non-null  object
#  2   description                             67827 non-null  object
#  3   host_id                                 69054 non-null  int64
#  4   host_location                           56983 non-null  category
#  5   host_listings_count                     69054 non-null  UInt16
#  6   host_total_listings_count               69054 non-null  UInt16
#  7   neighbourhood_cleansed                  69054 non-null  object
#  8   latitude                                69054 non-null  float64
#  9   longitude                               69054 non-null  float64
#  10  property_type                           69054 non-null  category
#  11  room_type                               69054 non-null  category
#  12  price                                   69054 non-null  float64
#  13  minimum_nights                          69054 non-null  int64
#  14  maximum_nights                          69054 non-null  int64
#  15  geometryneighbourhood_cleansed          69054 non-null  object
#  16  Unnamed: 0                              69054 non-null  int64
#  17  Area                                    69054 non-null  object
#  18  Repossessions                           56705 non-null  float64
#  19  NAME                                    69054 non-null  object
#  20  GSS_CODE                                69054 non-null  object
#  21  HECTARES                                69054 non-null  float64
#  22  NONLD_AREA                              69054 non-null  float64
#  23  ONS_INNER                               69054 non-null  object
#  24  geometryArea                            69054 non-null  object
#  25  area                                    69054 non-null  float64
#  26  density                                 56705 non-null  float64
#  27  Standardised Evictions                  56705 non-null  float64
#  28  Barriers to Housing and Services Score  69054 non-null  float64
# dtypes: UInt16(2), category(3), float64(10), int64(5), object(9)
# memory usage: 13.9+ MB

# %%
airbnb_merged2.sample(5)
# Out:
#                        id                                               name  \
# 65018            19688000     3 Bedr riverside apartment North Greenwich 090
# 2493             38202811                         Islington roof garden flat
# 30217  581232071517825536                   3 bedroom house in Parsons Green
# 19277            53410932  Private MODERN Studio Central London, Zone 1, W1.
# 40064  683169543464479744   Double Bedroom KX - Your Place in Central London
#
#                                              description    host_id  \
# 65018  This beautiful modern three bedroom apartment ...    1409439
# 2493   Hello,<br />The flat is much loved and lived i...   44011905
# 30217  Three bedroom family home in Fulham. The house...    3729906
# 19277  A Stylish & Modern studio flat in Central Lond...  392279502
# 40064  Stay in Central London, where you can have acc...  457104205
#
#                  host_location  host_listings_count  \
# 65018   London, United Kingdom                   27
# 2493   England, United Kingdom                    2
# 30217   London, United Kingdom                    1
# 19277   London, United Kingdom                   14
# 40064                      NaN                    6
#
#        host_total_listings_count  neighbourhood_cleansed  latitude  longitude  \
# 65018                         75               Greenwich     51.50       0.01
# 2493                           4               Islington     51.55      -0.11
# 30217                          4  Hammersmith and Fulham     51.48      -0.21
# 19277                         18             Westminster     51.52      -0.16
# 40064                          6                  Camden     51.53      -0.12
#
#        ...                    NAME   GSS_CODE  HECTARES  NONLD_AREA  \
# 65018  ...               Greenwich  E09000011  5,044.19      310.79
# 2493   ...               Islington  E09000019  1,485.66        0.00
# 30217  ...  Hammersmith and Fulham  E09000013  1,715.41       75.65
# 19277  ...             Westminster  E09000033  2,203.01       54.31
# 40064  ...                  Camden  E09000007  2,178.93        0.00
#
#        ONS_INNER                                       geometryArea  \
# 65018          F  MULTIPOLYGON (((537238.7 178137.7, 537242.6 17...
# 2493           T  MULTIPOLYGON (((529153.6 185861.4, 529144.8 18...
# 30217          T  MULTIPOLYGON (((521975.8 178100, 521973 178109...
# 19277          T  MULTIPOLYGON (((528549.5 177903.8, 528542.6 17...
# 40064          T  MULTIPOLYGON (((528840.2 187217.8, 528834.6 18...
#
#                area density  Standardised Evictions  \
# 65018 47,334,072.53    0.15                    1.00
# 2493  14,856,652.55     NaN                     NaN
# 30217 16,397,617.54     NaN                     NaN
# 19277 21,486,976.77    0.14                   -0.33
# 40064 21,789,295.89    0.14                   -0.33
#
#       Barriers to Housing and Services Score
# 65018                                  32.11
# 2493                                   28.00
# 30217                                  28.11
# 19277                                  23.20
# 40064                                  21.55
#
# [5 rows x 29 columns]

# %%
airbnb_merged2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69054 entries, 0 to 69053
# Data columns (total 29 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      69054 non-null  int64
#  1   name                                    69034 non-null  object
#  2   description                             67827 non-null  object
#  3   host_id                                 69054 non-null  int64
#  4   host_location                           56983 non-null  category
#  5   host_listings_count                     69054 non-null  UInt16
#  6   host_total_listings_count               69054 non-null  UInt16
#  7   neighbourhood_cleansed                  69054 non-null  object
#  8   latitude                                69054 non-null  float64
#  9   longitude                               69054 non-null  float64
#  10  property_type                           69054 non-null  category
#  11  room_type                               69054 non-null  category
#  12  price                                   69054 non-null  float64
#  13  minimum_nights                          69054 non-null  int64
#  14  maximum_nights                          69054 non-null  int64
#  15  geometryneighbourhood_cleansed          69054 non-null  object
#  16  Unnamed: 0                              69054 non-null  int64
#  17  Area                                    69054 non-null  object
#  18  Repossessions                           56705 non-null  float64
#  19  NAME                                    69054 non-null  object
#  20  GSS_CODE                                69054 non-null  object
#  21  HECTARES                                69054 non-null  float64
#  22  NONLD_AREA                              69054 non-null  float64
#  23  ONS_INNER                               69054 non-null  object
#  24  geometryArea                            69054 non-null  object
#  25  area                                    69054 non-null  float64
#  26  density                                 56705 non-null  float64
#  27  Standardised Evictions                  56705 non-null  float64
#  28  Barriers to Housing and Services Score  69054 non-null  float64
# dtypes: UInt16(2), category(3), float64(10), int64(5), object(9)
# memory usage: 13.9+ MB

# %%
airbnb_merged2 = gpd.GeoDataFrame(airbnb_merged2, geometry=gpd.points_from_xy(airbnb_merged2.longitude, airbnb_merged2.latitude))
airbnb_merged2.crs = {'init': 'epsg:4326'}
airbnb_merged2 = airbnb_merged2.to_crs('epsg:27700')
# Out:
# /opt/conda/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
airbnb_merged2.crs
# Out:
# <Derived Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.0, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
print(type(airbnb_merged2.geometry))
# Out:
# <class 'geopandas.geoseries.GeoSeries'>

# %%
airbnb_merged2.shape
# Out:
# (5713, 31)

# %%
airbnb_merged2.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 69054 entries, 0 to 69053
# Data columns (total 30 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      69054 non-null  int64
#  1   name                                    69034 non-null  object
#  2   description                             67827 non-null  object
#  3   host_id                                 69054 non-null  int64
#  4   host_location                           56983 non-null  category
#  5   host_listings_count                     69054 non-null  UInt16
#  6   host_total_listings_count               69054 non-null  UInt16
#  7   neighbourhood_cleansed                  69054 non-null  object
#  8   latitude                                69054 non-null  float64
#  9   longitude                               69054 non-null  float64
#  10  property_type                           69054 non-null  category
#  11  room_type                               69054 non-null  category
#  12  price                                   69054 non-null  float64
#  13  minimum_nights                          69054 non-null  int64
#  14  maximum_nights                          69054 non-null  int64
#  15  geometryneighbourhood_cleansed          69054 non-null  object
#  16  Unnamed: 0                              69054 non-null  int64
#  17  Area                                    69054 non-null  object
#  18  Repossessions                           56705 non-null  float64
#  19  NAME                                    69054 non-null  object
#  20  GSS_CODE                                69054 non-null  object
#  21  HECTARES                                69054 non-null  float64
#  22  NONLD_AREA                              69054 non-null  float64
#  23  ONS_INNER                               69054 non-null  object
#  24  geometryArea                            69054 non-null  object
#  25  area                                    69054 non-null  float64
#  26  density                                 56705 non-null  float64
#  27  Standardised Evictions                  56705 non-null  float64
#  28  Barriers to Housing and Services Score  69054 non-null  float64
#  29  geometry                                69054 non-null  geometry
# dtypes: UInt16(2), category(3), float64(10), geometry(1), int64(5), object(9)
# memory usage: 14.4+ MB

# %%
f,ax = plt.subplots(1,1,figsize=(12,8))

# The second one is on column2, spread on 3 columns
ax1 = plt.subplot2grid((4, 1), (0, 0), rowspan=3)
boros.plot(edgecolor='grey', facecolor='none', linewidth=1, alpha=0.75, ax=ax1)
airbnb_merged2.plot(markersize=2, column='Barriers to Housing and Services Score', cmap='Reds', alpha=0.2, scheme='Fisher_Jenks_Sampled', ax=ax1)

ax1.set_xlim([500000, 565000])
ax1.set_ylim([165000, 195000]);

# The last one is spread on 1 column only, on the 4th column of the second line.
ax2 = plt.subplot2grid((4, 1), (3, 0), rowspan=1)
airbnb_merged2[airbnb_merged2.price<airbnb_merged2.price.quantile(0.95)].price.plot.hist(bins=100, ax=ax2)
#ax2.set_ylim([0,10000])

plt.suptitle("Airbnbs Related to Deprivation")
# plt.savefig("Affordable_Listings.png", dpi=150)
plt.show()

# %% [markdown]
# ### Merging 2022 Airbnb Data & LSOA: Gentrification Regex

# %%
airbnb_merged1 = pd.merge(listings2022_gentrification, evict2022, how="inner", left_on='neighbourhood_cleansed', 
                          right_on='Area', suffixes=('neighbourhood_cleansed', 'Area'))

# %%
airbnb_merged2 = pd.merge(airbnb_merged1, London_borough_dep, how="inner", left_on='neighbourhood_cleansed', 
                          right_on='LAD', suffixes=('neighbourhood_cleansed', 'Area'))

# %%
airbnb_merged2 = gpd.GeoDataFrame(airbnb_merged2, geometry=gpd.points_from_xy(airbnb_merged2.longitude, airbnb_merged2.latitude))
airbnb_merged2.crs = {'init': 'epsg:4326'}
airbnb_merged2 = airbnb_merged2.to_crs('epsg:27700')
# Out:
# /opt/conda/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
airbnb_merged2.sample(5, random_state=42)
# Out:
#             id                                               name  \
# 1700  11732568                 Friendly room in trendy Haggerston
# 3269  49259438      PRIME LOCATION, BRIGHT AND CLEAN SINGLE ROOM.
# 561   48115315                    The Liverpool Street Collection
# 5466  42081823                  Locke at Broken Wharf River Suite
# 5280  17786350  New, clean and bright bedroom with Queensize bed.
#
#                                             description    host_id  \
# 1700  The room is a perfect spot for a weekend or mi...   43661091
# 3269  Bright, single bedroom located 10 minutes walk...  328039974
# 561   Please Note: We are a London based specialist ...  269308503
# 5466  Choose a River Suite for uninterrupted views o...  333684904
# 5280  Medium size, modern, clean and bright room. Wi...  108160366
#
#                 host_location  host_listings_count  host_total_listings_count  \
# 1700   London, United Kingdom                    1                          2
# 3269  England, United Kingdom                    1                          2
# 561    London, United Kingdom                   79                         86
# 5466                      NaN                    7                          7
# 5280   London, United Kingdom                    1                          2
#
#      neighbourhood_cleansed  latitude  longitude  ...   GSS_CODE HECTARES  \
# 1700                Hackney     51.54      -0.08  ...  E09000012 1,904.90
# 3269            Westminster     51.51      -0.13  ...  E09000033 2,203.01
# 561           Tower Hamlets     51.52      -0.08  ...  E09000030 2,157.50
# 5466         City of London     51.51      -0.10  ...  E09000001   314.94
# 5280         Waltham Forest     51.59      -0.02  ...  E09000031 3,880.79
#
#       NONLD_AREA  ONS_INNER  \
# 1700        0.00          T
# 3269       54.31          T
# 561       179.71          T
# 5466       24.55          T
# 5280        0.00          F
#
#                                            geometryArea          area density  \
# 1700  MULTIPOLYGON (((531928.4 187801.5, 531935.7 18... 19,049,027.67     NaN
# 3269  MULTIPOLYGON (((528549.5 177903.8, 528542.6 17... 21,486,976.77    0.14
# 561   MULTIPOLYGON (((533387.6 180516.4, 533389.8 18... 19,777,936.92    0.10
# 5466  MULTIPOLYGON (((531145.1 180782.1, 531143.8 18...  2,903,925.63     NaN
# 5280  MULTIPOLYGON (((539923.1 191863.1, 539928.1 19... 38,807,965.33    0.18
#
#       Standardised Evictions Barriers to Housing and Services Score  \
# 1700                     NaN                                  42.66
# 3269                   -0.33                                  23.20
# 561                    -0.67                                  30.32
# 5466                     NaN                                  36.27
# 5280                    1.00                                  36.25
#
#                            geometry
# 1700  POINT (533406.061 183909.491)
# 3269  POINT (530062.126 180269.672)
# 561   POINT (533532.082 181580.327)
# 5466  POINT (532280.086 180858.816)
# 5280  POINT (537277.597 189374.369)
#
# [5 rows x 31 columns]

# %%
f,ax = plt.subplots(1,1,figsize=(12,8))

# The second one is on column2, spread on 3 columns
ax1 = plt.subplot2grid((4, 1), (0, 0), rowspan=3)
boros.plot(edgecolor='grey', facecolor='none', linewidth=1, alpha=0.75, ax=ax1)
airbnb_merged2.plot(markersize=2, column='Barriers to Housing and Services Score', cmap='Reds', alpha=0.2, scheme='Fisher_Jenks_Sampled', ax=ax1)

ax1.set_xlim([500000, 565000])
ax1.set_ylim([165000, 195000]);

# The last one is spread on 1 column only, on the 4th column of the second line.
ax2 = plt.subplot2grid((4, 1), (3, 0), rowspan=1)
airbnb_merged2[airbnb_merged2.price<airbnb_merged2.price.quantile(0.95)].price.plot.hist(bins=100, ax=ax2)
#ax2.set_ylim([0,10000])

plt.suptitle("Airbnbs Filtered by Gentrification Related to Deprivation")
# plt.savefig("Affordable_Listings.png", dpi=150)
plt.show()

# %% [markdown]
# ### Merging 2022 Airbnb Data & LSOA: Kensington and Chelsea

# %%
listings2022_kensington_chelsea = gpd.GeoDataFrame(listings2022_kensington_chelsea, geometry=gpd.points_from_xy(listings2022_kensington_chelsea.longitude, listings2022_kensington_chelsea.latitude))
listings2022_kensington_chelsea.crs = {'init': 'epsg:4326'}
listings2022_kensington_chelsea = listings2022_kensington_chelsea.to_crs('epsg:27700')
# Out:
# /opt/conda/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
print(type(listings2022_kensington_chelsea.geometry))
# Out:
# <class 'geopandas.geoseries.GeoSeries'>

# %%
listings2022_kensington_chelsea.crs
# Out:
# <Derived Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.0, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
listings2022_kensington_chelsea.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 4596 entries, 1 to 69326
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         4596 non-null   int64
#  1   name                       4596 non-null   object
#  2   description                4535 non-null   object
#  3   host_id                    4596 non-null   int64
#  4   host_location              3718 non-null   category
#  5   host_listings_count        4596 non-null   UInt16
#  6   host_total_listings_count  4596 non-null   UInt16
#  7   neighbourhood_cleansed     4596 non-null   category
#  8   latitude                   4596 non-null   float64
#  9   longitude                  4596 non-null   float64
#  10  property_type              4596 non-null   category
#  11  room_type                  4596 non-null   category
#  12  price                      4596 non-null   float64
#  13  minimum_nights             4596 non-null   int64
#  14  maximum_nights             4596 non-null   int64
#  15  geometry                   4596 non-null   geometry
# dtypes: UInt16(2), category(4), float64(3), geometry(1), int64(4), object(2)
# memory usage: 494.9+ KB

# %%
lsoa_shp_file.columns.tolist()
# Out:
# ['LSOA11CD',
#  'LSOA11NM',
#  'MSOA11CD',
#  'MSOA11NM',
#  'LAD11CD',
#  'LAD11NM',
#  'RGN11CD',
#  'RGN11NM',
#  'USUALRES',
#  'HHOLDRES',
#  'COMESTRES',
#  'POPDEN',
#  'HHOLDS',
#  'AVHHOLDSZ',
#  'geometry']

# %%
kc_dep.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'LSOA11CD',
#  'LSOA11NM',
#  'geometry',
#  'LSOA code (2011)',
#  'Local Authority District code (2019)',
#  'LAD',
#  'Barriers to Housing and Services Score',
#  'Barriers to Housing and Services Rank (where 1 is most deprived)',
#  'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)',
#  'transformed_mms']

# %%
kc_dep2 = lsoa_shp_file.merge(kc_dep, how="inner", left_on='LSOA11CD', right_on='LSOA11CD')

# %%
kc_dep2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 25 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   LSOA11CD                                                                         103 non-null    object
#  1   LSOA11NM_x                                                                       103 non-null    object
#  2   MSOA11CD                                                                         103 non-null    object
#  3   MSOA11NM                                                                         103 non-null    object
#  4   LAD11CD                                                                          103 non-null    object
#  5   LAD11NM                                                                          103 non-null    object
#  6   RGN11CD                                                                          103 non-null    object
#  7   RGN11NM                                                                          103 non-null    object
#  8   USUALRES                                                                         103 non-null    int64
#  9   HHOLDRES                                                                         103 non-null    int64
#  10  COMESTRES                                                                        103 non-null    int64
#  11  POPDEN                                                                           103 non-null    float64
#  12  HHOLDS                                                                           103 non-null    int64
#  13  AVHHOLDSZ                                                                        103 non-null    float64
#  14  geometry_x                                                                       103 non-null    geometry
#  15  Unnamed: 0                                                                       103 non-null    int64
#  16  LSOA11NM_y                                                                       103 non-null    object
#  17  geometry_y                                                                       103 non-null    object
#  18  LSOA code (2011)                                                                 103 non-null    object
#  19  Local Authority District code (2019)                                             103 non-null    object
#  20  LAD                                                                              103 non-null    object
#  21  Barriers to Housing and Services Score                                           103 non-null    float64
#  22  Barriers to Housing and Services Rank (where 1 is most deprived)                 103 non-null    int64
#  23  Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  103 non-null    int64
#  24  transformed_mms                                                                  103 non-null    float64
# dtypes: float64(4), geometry(1), int64(7), object(13)
# memory usage: 20.9+ KB

# %%
kc_dep3 = gpd.GeoDataFrame(kc_dep2, geometry='geometry_x')
kc_dep3.crs = {'init': 'epsg:4326'}
kc_dep3 = kc_dep3.to_crs('epsg:27700')
# Out:
# /opt/conda/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
print(type(kc_dep3.geometry))
# Out:
# <class 'geopandas.geoseries.GeoSeries'>

# %%
kc_dep3.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 25 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   LSOA11CD                                                                         103 non-null    object
#  1   LSOA11NM_x                                                                       103 non-null    object
#  2   MSOA11CD                                                                         103 non-null    object
#  3   MSOA11NM                                                                         103 non-null    object
#  4   LAD11CD                                                                          103 non-null    object
#  5   LAD11NM                                                                          103 non-null    object
#  6   RGN11CD                                                                          103 non-null    object
#  7   RGN11NM                                                                          103 non-null    object
#  8   USUALRES                                                                         103 non-null    int64
#  9   HHOLDRES                                                                         103 non-null    int64
#  10  COMESTRES                                                                        103 non-null    int64
#  11  POPDEN                                                                           103 non-null    float64
#  12  HHOLDS                                                                           103 non-null    int64
#  13  AVHHOLDSZ                                                                        103 non-null    float64
#  14  geometry_x                                                                       103 non-null    geometry
#  15  Unnamed: 0                                                                       103 non-null    int64
#  16  LSOA11NM_y                                                                       103 non-null    object
#  17  geometry_y                                                                       103 non-null    object
#  18  LSOA code (2011)                                                                 103 non-null    object
#  19  Local Authority District code (2019)                                             103 non-null    object
#  20  LAD                                                                              103 non-null    object
#  21  Barriers to Housing and Services Score                                           103 non-null    float64
#  22  Barriers to Housing and Services Rank (where 1 is most deprived)                 103 non-null    int64
#  23  Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  103 non-null    int64
#  24  transformed_mms                                                                  103 non-null    float64
# dtypes: float64(4), geometry(1), int64(7), object(13)
# memory usage: 20.9+ KB

# %%
listings2022_kensington_chelsea.head(n=3)
# Out:
#         id                                 name  \
# 1    15400  Bright Chelsea  Apartment. Chelsea!
# 7   284603  Notting Hill church stay in Heaven!
# 60  165336        Charming Flat in Notting Hill
#
#                                           description  host_id  \
# 1   Lots of windows and light.  St Luke's Gardens ...    60302
# 7   <b>The space</b><br />Overview:<br /><br />Loc...  1481851
# 60  A stylish apartment close to Portobello market...   761400
#
#                  host_location  host_listings_count  \
# 1   Kensington, United Kingdom                    1
# 7       London, United Kingdom                    1
# 60      London, United Kingdom                    1
#
#     host_total_listings_count  neighbourhood_cleansed  latitude  longitude  \
# 1                          12  Kensington and Chelsea     51.49      -0.17
# 7                           2  Kensington and Chelsea     51.51      -0.20
# 60                          1  Kensington and Chelsea     51.52      -0.21
#
#          property_type        room_type  price  minimum_nights  \
# 1   Entire rental unit  Entire home/apt  75.00               3
# 7   Entire rental unit  Entire home/apt 297.00              14
# 60  Entire rental unit  Entire home/apt 100.00               1
#
#     maximum_nights                       geometry
# 1               50  POINT (527284.576 178129.679)
# 7              365  POINT (524995.812 181059.452)
# 60              14  POINT (524244.638 181342.578)

# %%
kc_dep3.head(n=2)
# Out:
#     LSOA11CD                   LSOA11NM_x   MSOA11CD  \
# 0  E01002812  Kensington and Chelsea 013A  E02000589
# 1  E01002813  Kensington and Chelsea 011A  E02000587
#
#                      MSOA11NM    LAD11CD                 LAD11NM    RGN11CD  \
# 0  Kensington and Chelsea 013  E09000020  Kensington and Chelsea  E12000007
# 1  Kensington and Chelsea 011  E09000020  Kensington and Chelsea  E12000007
#
#   RGN11NM  USUALRES  HHOLDRES  ...  Unnamed: 0                   LSOA11NM_y  \
# 0  London      1917      1763  ...        2747  Kensington and Chelsea 013A
# 1  London      1767      1767  ...        2748  Kensington and Chelsea 011A
#
#                                           geometry_y  LSOA code (2011)  \
# 0  POLYGON ((525802.22499993 179074.02600009655, ...         E01002812
# 1  POLYGON ((525387.795999887 179246.17700007392,...         E01002813
#
#   Local Authority District code (2019)                     LAD  \
# 0                            E09000020  Kensington and Chelsea
# 1                            E09000020  Kensington and Chelsea
#
#   Barriers to Housing and Services Score  \
# 0                                  40.75
# 1                                  27.38
#
#   Barriers to Housing and Services Rank (where 1 is most deprived)  \
# 0                                               1981
# 1                                               8934
#
#   Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  1
# 1                                                  3
#
#   transformed_mms
# 0            0.53
# 1            0.32
#
# [2 rows x 25 columns]

# %%
print(kc_dep3.crs)
#print(listings2022_kensington_chelsea)
# Out:
# epsg:27700

# %%
polygon_df = kc_dep3.set_crs(kc_dep3.crs,allow_override=True).to_crs("EPSG:27700")

listings2022_kensington_chelsea.to_crs(epsg=27700)
#kc_dep3.to_crs(epsg=27700)

new_df = gpd.sjoin(listings2022_kensington_chelsea, polygon_df, how = 'inner', 
                  predicate = 'within')

new_df
# Out:
# Empty GeoDataFrame
# Columns: [id, name, description, host_id, host_location, host_listings_count, host_total_listings_count, neighbourhood_cleansed, latitude, longitude, property_type, room_type, price, minimum_nights, maximum_nights, geometry, index_right, LSOA11CD, LSOA11NM_x, MSOA11CD, MSOA11NM, LAD11CD, LAD11NM, RGN11CD, RGN11NM, USUALRES, HHOLDRES, COMESTRES, POPDEN, HHOLDS, AVHHOLDSZ, Unnamed: 0, LSOA11NM_y, geometry_y, LSOA code (2011), Local Authority District code (2019), LAD, Barriers to Housing and Services Score, Barriers to Housing and Services Rank (where 1 is most deprived), Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs), transformed_mms]
# Index: []
#
# [0 rows x 41 columns]

# %%
# Create a boolean mask indicating which points fall within the polygons
mask = listings2022_kensington_chelsea.geometry.within(kc_dep3.geometry_x.unary_union)

# Subset the point data to only include points within the polygons
points_within_polygons = listings2022_kensington_chelsea.geometry.loc[mask]

# Create the map figure and axis
fig, ax = plt.subplots()

# Plot the polygons on the map
kc_dep3.geometry_x.plot(ax=ax, color='white', edgecolor='black')

# Plot the point data on top of the polygons
points_within_polygons.plot(ax=ax, markersize=5, color='red')

# Show the map
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/pygeos/set_operations.py:388: RuntimeWarning: invalid value encountered in unary_union
#   result = lib.unary_union(collections, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pygeos/predicates.py:906: RuntimeWarning: invalid value encountered in within
#   return lib.within(a, b, **kwargs)
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:402: UserWarning: The GeoSeries you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(

# %%
points_within_polygons = gpd.sjoin(listings2022_kensington_chelsea, kc_dep3, predicate='within')

# %%
points_within_polygons.head(n=1)
# Out:
# Empty GeoDataFrame
# Columns: [id, name, description, host_id, host_location, host_listings_count, host_total_listings_count, neighbourhood_cleansed, latitude, longitude, property_type, room_type, price, minimum_nights, maximum_nights, geometry, index_right, LSOA11CD, LSOA11NM_x, MSOA11CD, MSOA11NM, LAD11CD, LAD11NM, RGN11CD, RGN11NM, USUALRES, HHOLDRES, COMESTRES, POPDEN, HHOLDS, AVHHOLDSZ, Unnamed: 0, LSOA11NM_y, geometry_y, LSOA code (2011), Local Authority District code (2019), LAD, Barriers to Housing and Services Score, Barriers to Housing and Services Rank (where 1 is most deprived), Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs), transformed_mms]
# Index: []
#
# [0 rows x 41 columns]

# %%
kc_merged.head(n=3)

# %%
# kc_merged = gpd.sjoin(listings2022_kensington_chelsea, kc_dep, how='inner', predicate='within', 
#                       left_on='geometry', right_on='geometry')

# %%
kc_merged = kc_merged.set_geometry('geometry_x')
kc_merged.plot(column='Barriers to Housing and Services Score', legend=True, figsize=(8,8), scheme='user_defined', classification_kwds={'bins':[5,10,15,20,25,30,35,40,45,50,55,60,65,70]},cmap = 'Reds');

# %%
f,ax = plt.subplots(1,1,figsize=(12,8))

# The second one is on column2, spread on 3 columns
ax1 = plt.subplot2grid((4, 1), (0, 0), rowspan=3)
boros.plot(edgecolor='grey', facecolor='none', linewidth=1, alpha=0.75, ax=ax1)
kc_merged.plot(markersize=2, column='Barriers to Housing and Services Score', cmap='Reds', alpha=0.2, scheme='Fisher_Jenks_Sampled', ax=ax1)

# ax1.set_xlim([500000, 565000])
# ax1.set_ylim([165000, 195000]);

# The last one is spread on 1 column only, on the 4th column of the second line.
# ax2 = plt.subplot2grid((4, 1), (3, 0), rowspan=1)
# kc_merged[kc_merged.price<kc_merged.price.quantile(0.95)].price.plot.hist(bins=100, ax=ax2)
#ax2.set_ylim([0,10000])

plt.suptitle("Listings Advertising using Language related to Gentrification")
# plt.savefig("Affordable_Listings.png", dpi=150)
plt.show()

# %% [markdown]
# ### Merging 2022 Airbnb Data: Camden

# %% [markdown]
# ### Merging 2022 Airbnb Data: Hackney

# %%
listings2022_hackney = gpd.GeoDataFrame(listings2022_hackney, geometry=gpd.points_from_xy(listings2022_hackney.longitude, listings2022_hackney.latitude))
listings2022_hackney.crs = {'init': 'epsg:4326'}
listings2022_hackney = listings2022_hackney.to_crs('epsg:27700')
# Out:
# /opt/conda/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
listings2022_hackney.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5164 entries, 28 to 68567
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         5164 non-null   int64
#  1   name                       5162 non-null   object
#  2   description                5098 non-null   object
#  3   host_id                    5164 non-null   int64
#  4   host_location              4647 non-null   category
#  5   host_listings_count        5164 non-null   UInt16
#  6   host_total_listings_count  5164 non-null   UInt16
#  7   neighbourhood_cleansed     5164 non-null   category
#  8   latitude                   5164 non-null   float64
#  9   longitude                  5164 non-null   float64
#  10  property_type              5164 non-null   category
#  11  room_type                  5164 non-null   category
#  12  price                      5164 non-null   float64
#  13  minimum_nights             5164 non-null   int64
#  14  maximum_nights             5164 non-null   int64
#  15  geometry                   5164 non-null   geometry
# dtypes: UInt16(2), category(4), float64(3), geometry(1), int64(4), object(2)
# memory usage: 549.8+ KB

# %%
hackney_dep = lsoa_shp_file.merge(hackney_dep, how="inner", left_on='LSOA11CD', right_on='LSOA11CD')

# %%
hackney_dep.head(5)
# Out:
#     LSOA11CD    LSOA11NM_x   MSOA11CD     MSOA11NM    LAD11CD  LAD11NM  \
# 0  E01001714  Hackney 002A  E02000346  Hackney 002  E09000012  Hackney
# 1  E01001715  Hackney 007A  E02000351  Hackney 007  E09000012  Hackney
# 2  E01001716  Hackney 007B  E02000351  Hackney 007  E09000012  Hackney
# 3  E01001717  Hackney 007C  E02000351  Hackney 007  E09000012  Hackney
# 4  E01001718  Hackney 007D  E02000351  Hackney 007  E09000012  Hackney
#
#      RGN11CD RGN11NM  USUALRES  HHOLDRES  ...  Unnamed: 0    LSOA11NM_y  \
# 0  E12000007  London      1490      1468  ...        1676  Hackney 002A
# 1  E12000007  London      1321      1316  ...        1677  Hackney 007A
# 2  E12000007  London      1318      1260  ...        1678  Hackney 007B
# 3  E12000007  London      1222      1222  ...        1679  Hackney 007C
# 4  E12000007  London      1787      1787  ...        1680  Hackney 007D
#
#                                           geometry_y  LSOA code (2011)  \
# 0  POLYGON ((532084.8620000243 187425.27800004705...         E01001714
# 1  POLYGON ((531971.5360000525 187248.00699991966...         E01001715
# 2  POLYGON ((531916.380000002 187056.60500008028,...         E01001716
# 3  POLYGON ((532205.0979999949 187016.36199987744...         E01001717
# 4  POLYGON ((531727.2930000254 186813.98100011528...         E01001718
#
#   Local Authority District code (2019)      LAD  \
# 0                            E09000012  Hackney
# 1                            E09000012  Hackney
# 2                            E09000012  Hackney
# 3                            E09000012  Hackney
# 4                            E09000012  Hackney
#
#   Barriers to Housing and Services Score  \
# 0                                  45.51
# 1                                  46.81
# 2                                  47.81
# 3                                  47.27
# 4                                  39.69
#
#   Barriers to Housing and Services Rank (where 1 is most deprived)  \
# 0                                                968
# 1                                                746
# 2                                                590
# 3                                                666
# 4                                               2290
#
#   Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#   transformed_mms
# 0            0.61
# 1            0.63
# 2            0.64
# 3            0.64
# 4            0.52
#
# [5 rows x 25 columns]

# %%
hackney_dep.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 25 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   LSOA11CD                                                                         144 non-null    object
#  1   LSOA11NM_x                                                                       144 non-null    object
#  2   MSOA11CD                                                                         144 non-null    object
#  3   MSOA11NM                                                                         144 non-null    object
#  4   LAD11CD                                                                          144 non-null    object
#  5   LAD11NM                                                                          144 non-null    object
#  6   RGN11CD                                                                          144 non-null    object
#  7   RGN11NM                                                                          144 non-null    object
#  8   USUALRES                                                                         144 non-null    int64
#  9   HHOLDRES                                                                         144 non-null    int64
#  10  COMESTRES                                                                        144 non-null    int64
#  11  POPDEN                                                                           144 non-null    float64
#  12  HHOLDS                                                                           144 non-null    int64
#  13  AVHHOLDSZ                                                                        144 non-null    float64
#  14  geometry_x                                                                       144 non-null    geometry
#  15  Unnamed: 0                                                                       144 non-null    int64
#  16  LSOA11NM_y                                                                       144 non-null    object
#  17  geometry_y                                                                       144 non-null    object
#  18  LSOA code (2011)                                                                 144 non-null    object
#  19  Local Authority District code (2019)                                             144 non-null    object
#  20  LAD                                                                              144 non-null    object
#  21  Barriers to Housing and Services Score                                           144 non-null    float64
#  22  Barriers to Housing and Services Rank (where 1 is most deprived)                 144 non-null    int64
#  23  Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  144 non-null    int64
#  24  transformed_mms                                                                  144 non-null    float64
# dtypes: float64(4), geometry(1), int64(7), object(13)
# memory usage: 29.2+ KB

# %%
to_drop = ['LSOA11NM_x', 'MSOA11CD','MSOA11NM','LAD11CD','LAD11NM','RGN11CD','RGN11NM',
 'USUALRES','HHOLDRES','COMESTRES','POPDEN','HHOLDS','AVHHOLDSZ','geometry_y','Unnamed: 0', 'LSOA11NM_y']
hackney_dep2 = hackney_dep.drop(axis=1, columns=to_drop)
#transformed mms comes from the eviction dataset where I used min-max scaler to standardise the eviction data

# %%
hackney_dep2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 9 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   LSOA11CD                                                                         144 non-null    object
#  1   geometry_x                                                                       144 non-null    geometry
#  2   LSOA code (2011)                                                                 144 non-null    object
#  3   Local Authority District code (2019)                                             144 non-null    object
#  4   LAD                                                                              144 non-null    object
#  5   Barriers to Housing and Services Score                                           144 non-null    float64
#  6   Barriers to Housing and Services Rank (where 1 is most deprived)                 144 non-null    int64
#  7   Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  144 non-null    int64
#  8   transformed_mms                                                                  144 non-null    float64
# dtypes: float64(2), geometry(1), int64(2), object(4)
# memory usage: 11.2+ KB

# %%
Hackg = hackney_dep2.set_geometry('geometry_x')
Hackg.plot(column='Barriers to Housing and Services Score', legend=True, 
             figsize=(8,8), scheme='Fisher_Jenks_Sampled',cmap = 'Reds');

# %%
hack_list = listings2022_hackney.merge(hackney_dep2, how="left", left_on='neighbourhood_cleansed', right_on='LAD')

# %%
hack_list2 = hack_list.groupby('LSOA11CD').agg({'id': 'first','name': 'first','description': 'first','host_id': 'first','host_location': 'first','host_listings_count': 'first','host_total_listings_count': 'first','neighbourhood_cleansed': 'first','latitude': 'first','longitude': 'first','property_type': 'first','room_type': 'first','price': 'first','minimum_nights': 'first','maximum_nights': 'first','geometry': 'first','geometry_x': 'first','LSOA code (2011)': 'first','Local Authority District code (2019)': 'first','LAD': 'first','Barriers to Housing and Services Score': 'mean','Barriers to Housing and Services Rank (where 1 is most deprived)': 'first','Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)': 'first','transformed_mms': 'first'})

# %%
hack_list2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, E01001714 to E01033713
# Data columns (total 24 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   id                                                                               144 non-null    int64
#  1   name                                                                             144 non-null    object
#  2   description                                                                      144 non-null    object
#  3   host_id                                                                          144 non-null    int64
#  4   host_location                                                                    144 non-null    category
#  5   host_listings_count                                                              144 non-null    UInt16
#  6   host_total_listings_count                                                        144 non-null    UInt16
#  7   neighbourhood_cleansed                                                           144 non-null    object
#  8   latitude                                                                         144 non-null    float64
#  9   longitude                                                                        144 non-null    float64
#  10  property_type                                                                    144 non-null    category
#  11  room_type                                                                        144 non-null    category
#  12  price                                                                            144 non-null    float64
#  13  minimum_nights                                                                   144 non-null    int64
#  14  maximum_nights                                                                   144 non-null    int64
#  15  geometry                                                                         144 non-null    geometry
#  16  geometry_x                                                                       144 non-null    geometry
#  17  LSOA code (2011)                                                                 144 non-null    object
#  18  Local Authority District code (2019)                                             144 non-null    object
#  19  LAD                                                                              144 non-null    object
#  20  Barriers to Housing and Services Score                                           144 non-null    float64
#  21  Barriers to Housing and Services Rank (where 1 is most deprived)                 144 non-null    int64
#  22  Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  144 non-null    int64
#  23  transformed_mms                                                                  144 non-null    float64
# dtypes: UInt16(2), category(3), float64(5), geometry(2), int64(6), object(6)
# memory usage: 73.1+ KB

# %%
hack_list2 = gpd.GeoDataFrame(hack_list2, geometry=gpd.points_from_xy(hack_list2.longitude, hack_list2.latitude))
hack_list2.crs = {'init': 'epsg:4326'}
hack_list2 = hack_list2.to_crs('epsg:27700')
# Out:
# /opt/conda/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
hack_list2.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 144 entries, E01001714 to E01033713
# Data columns (total 24 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   id                                                                               144 non-null    int64
#  1   name                                                                             144 non-null    object
#  2   description                                                                      144 non-null    object
#  3   host_id                                                                          144 non-null    int64
#  4   host_location                                                                    144 non-null    category
#  5   host_listings_count                                                              144 non-null    UInt16
#  6   host_total_listings_count                                                        144 non-null    UInt16
#  7   neighbourhood_cleansed                                                           144 non-null    object
#  8   latitude                                                                         144 non-null    float64
#  9   longitude                                                                        144 non-null    float64
#  10  property_type                                                                    144 non-null    category
#  11  room_type                                                                        144 non-null    category
#  12  price                                                                            144 non-null    float64
#  13  minimum_nights                                                                   144 non-null    int64
#  14  maximum_nights                                                                   144 non-null    int64
#  15  geometry                                                                         144 non-null    geometry
#  16  geometry_x                                                                       144 non-null    geometry
#  17  LSOA code (2011)                                                                 144 non-null    object
#  18  Local Authority District code (2019)                                             144 non-null    object
#  19  LAD                                                                              144 non-null    object
#  20  Barriers to Housing and Services Score                                           144 non-null    float64
#  21  Barriers to Housing and Services Rank (where 1 is most deprived)                 144 non-null    int64
#  22  Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  144 non-null    int64
#  23  transformed_mms                                                                  144 non-null    float64
# dtypes: UInt16(2), category(3), float64(5), geometry(2), int64(6), object(6)
# memory usage: 77.2+ KB

# %%
# hackg.info(verbose=True)

# %%
hackg_mean = hackg.groupby('LSOA11CD').agg({'geometry_x': 'first', 'LSOA code (2011)': 'first', 'Local Authority District code (2019)': 'first','LAD': 'first','Barriers to Housing and Services Score': 'mean','Barriers to Housing and Services Rank (where 1 is most deprived)': 'first'
                                            ,'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)': 'first','transformed_mms': 'first'})

# %%
hackg_mean = hackg_mean.set_geometry('geometry_x')
hackg_mean = hackg_mean.set_crs(epsg=27700, allow_override=True)

# %% [markdown]
# # THIS IS THE KEY TO THE CODE: maybe lol

# %%
# hackg['buffered'] = hackg.geometry_x.buffer(250)
# hackg = hackg.set_geometry('buffered').set_crs(epsg=27700)

# %%
# # hack_merged = gpd.sjoin(hackg, listings2022_hackney, op="within")
# intersection_df = gpd.overlay(hackg, listings2022_hackney, how='intersection')
# Out:
# /tmp/ipykernel_161/597705312.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 28698 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   intersection_df = gpd.overlay(hackg, listings2022_hackney, how='intersection')

# %%
# from shapely.ops import snap

# # Perform the snap operation on the intersection points
# hack_merged['geometry_new'] = hack_merged2.apply(lambda x: snap(x.geometry,
#                                                                    listings2022_hackney.unary_union, tolerance=0.1), axis=1)

# %%
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

norm = Normalize(vmin=hack_list2['Barriers to Housing and Services Score'].min(), 
                 vmax=hack_list2['Barriers to Housing and Services Score'].max())

colormap = ScalarMappable(norm=norm, cmap='cool')

ax.scatter(x=listings2022_hackney.geometry.x, y=listings2022_hackney.geometry.y, c=colormap.to_rgba(hack_list2['Barriers to Housing and Services Score']), s=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [145], in <cell line: 9>()
#       4 norm = Normalize(vmin=hack_list2['Barriers to Housing and Services Score'].min(),
#       5                  vmax=hack_list2['Barriers to Housing and Services Score'].max())
#       7 colormap = ScalarMappable(norm=norm, cmap='cool')
# ----> 9 ax.scatter(x=listings2022_hackney.geometry.x, y=listings2022_hackney.geometry.y, c=colormap.to_rgba(hack_list2['Barriers to Housing and Services Score']), s=5)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4380, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4377 if edgecolors is None:
#    4378     orig_edgecolor = kwargs.get('edgecolor', None)
#    4379 c, colors, edgecolors = \
# -> 4380     self._parse_scatter_color_args(
#    4381         c, edgecolors, kwargs, x.size,
#    4382         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4384 if plotnonfinite and colors is None:
#    4385     c = np.ma.masked_invalid(c)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4230, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4226     else:
#    4227         if len(colors) not in (0, 1, xsize):
#    4228             # NB: remember that a single color is also acceptable.
#    4229             # Besides *colors* will be an empty array if c == 'none'.
# -> 4230             raise invalid_shape_exception(len(colors), xsize)
#    4231 else:
#    4232     colors = None  # use cmap, norm after collection is created
#
# ValueError: 'c' argument has 144 elements, which is inconsistent with 'x' and 'y' with size 5164.

# %%
# Create the map figure and axis
fig, ax = plt.subplots()

# Plot the polygons on the map
hackg_mean.plot(ax=ax, color='white', edgecolor='black')

# Plot the points on top of the polygons
ax.scatter(x=hack_list2.geometry.x, y=hack_list2.geometry.y, c=hack_list2['Barriers to Housing and Services Score'], cmap='cool', s=5)

plt.show()

# %%
hack_merged.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 28698 entries, 0 to 138
# Data columns (total 43 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   LSOA11CD                                                                         28698 non-null  object
#  1   LSOA11NM_x                                                                       28698 non-null  object
#  2   MSOA11CD                                                                         28698 non-null  object
#  3   MSOA11NM                                                                         28698 non-null  object
#  4   LAD11CD                                                                          28698 non-null  object
#  5   LAD11NM                                                                          28698 non-null  object
#  6   RGN11CD                                                                          28698 non-null  object
#  7   RGN11NM                                                                          28698 non-null  object
#  8   USUALRES                                                                         28698 non-null  int64
#  9   HHOLDRES                                                                         28698 non-null  int64
#  10  COMESTRES                                                                        28698 non-null  int64
#  11  POPDEN                                                                           28698 non-null  float64
#  12  HHOLDS                                                                           28698 non-null  int64
#  13  AVHHOLDSZ                                                                        28698 non-null  float64
#  14  geometry_x                                                                       28698 non-null  geometry
#  15  Unnamed: 0                                                                       28698 non-null  int64
#  16  LSOA11NM_y                                                                       28698 non-null  object
#  17  geometry_y                                                                       28698 non-null  object
#  18  LSOA code (2011)                                                                 28698 non-null  object
#  19  Local Authority District code (2019)                                             28698 non-null  object
#  20  LAD                                                                              28698 non-null  object
#  21  Barriers to Housing and Services Score                                           28698 non-null  float64
#  22  Barriers to Housing and Services Rank (where 1 is most deprived)                 28698 non-null  int64
#  23  Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  28698 non-null  int64
#  24  transformed_mms                                                                  28698 non-null  float64
#  25  buffered                                                                         28698 non-null  geometry
#  26  index_right                                                                      28698 non-null  int64
#  27  id                                                                               28698 non-null  int64
#  28  name                                                                             28686 non-null  object
#  29  description                                                                      28343 non-null  object
#  30  host_id                                                                          28698 non-null  int64
#  31  host_location                                                                    25961 non-null  category
#  32  host_listings_count                                                              28698 non-null  UInt16
#  33  host_total_listings_count                                                        28698 non-null  UInt16
#  34  neighbourhood_cleansed                                                           28698 non-null  category
#  35  latitude                                                                         28698 non-null  float64
#  36  longitude                                                                        28698 non-null  float64
#  37  property_type                                                                    28698 non-null  category
#  38  room_type                                                                        28698 non-null  category
#  39  price                                                                            28698 non-null  float64
#  40  minimum_nights                                                                   28698 non-null  int64
#  41  maximum_nights                                                                   28698 non-null  int64
#  42  geometry_new                                                                     2027 non-null   geometry
# dtypes: UInt16(2), category(4), float64(7), geometry(3), int64(12), object(15)
# memory usage: 8.7+ MB

# %%
hack_merged.plot(column='Barriers to Housing and Services Score', legend=True, 
             figsize=(8,8), scheme='Fisher_Jenks_Sampled',cmap = 'viridis');

# %%
hack_merged.plot(markersize=0.01, legend=True, 
             figsize=(8,8), scheme='Fisher_Jenks_Sampled',cmap = 'Reds');

# %%
hack_merged.plot(markersize=1,column='Barriers to Housing and Services Score', legend=True, 
             figsize=(8,8), scheme='user_defined', classification_kwds={'bins':[10,20,30,40,50,60,70]},cmap = 'Reds');

# %%
#they merged I think but now gotta map

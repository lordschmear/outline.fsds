# %% [markdown]
# # Cleaning and Analysing Eviction Data
# Source: https://data.london.gov.uk/dataset/mortgage-and-landlord-possession-actions-borough

# %% [markdown]
# ### Importing Packages and Functions

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib as mpl
import re
import math

from matplotlib.colors import ListedColormap

# All of these are potentially useful, though
# not all have been used in this practical --
# I'd suggest exploring the use of different 
# Scalers/Transformers as well as clustering 
# algorithms...
import sklearn
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, PowerTransformer
from sklearn.cluster import KMeans, DBSCAN, OPTICS
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import random
random.seed(42)    # For reproducibility
np.random.seed(42) # For reproducibility

# Make numeric display a bit neater
pd.set_option('display.float_format', lambda x: '{:,.2f}'.format(x))
# Out:
# <jemalloc>: MADV_DONTNEED does not work (memset will be used instead)
# <jemalloc>: (This is the expected behaviour if you are running under QEMU)

# %%
mms  = MinMaxScaler(feature_range=(0,1))
stds = StandardScaler()
rbs  = RobustScaler()
pts  = PowerTransformer()

# %%
# These are specific to NLP
import nltk
import spacy
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer

from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize.toktok import ToktokTokenizer

from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

from nltk import ngrams, FreqDist

lemmatizer = WordNetLemmatizer()
tokenizer = ToktokTokenizer()
mms  = MinMaxScaler(feature_range=(-1,1))
stds = StandardScaler()
rbs  = RobustScaler()
pts  = PowerTransformer()

import string
import unicodedata
from bs4 import BeautifulSoup
from wordcloud import WordCloud, STOPWORDS

# %%
# This is the Cache Function Jon wrote
import os
from requests import get
from urllib.parse import urlparse

def cache_data(src:str, dest:str) -> str:
    """Downloads and caches a remote file locally.
    
    The function sits between the 'read' step of a pandas or geopandas
    data frame and downloading the file from a remote location. The idea
    is that it will save it locally so that you don't need to remember to
    do so yourself. Subsequent re-reads of the file will return instantly
    rather than downloading the entire file for a second or n-th itme.
    
    Parameters
    ----------
    src : str
        The remote *source* for the file, any valid URL should work.
    dest : str
        The *destination* location to save the downloaded file.
        
    Returns
    -------
    str
        A string representing the local location of the file.
    """
    
    url = urlparse(src) # We assume that this is some kind of valid URL 
    fn  = os.path.split(url.path)[-1] # Extract the filename
    dfn = os.path.join(dest,fn) # Destination filename
    
    # Check if dest+filename does *not* exist -- 
    # that would mean we have to download it!
    if not os.path.isfile(dfn) or os.path.getsize(dfn) < 1:
        
        print(f"{dfn} not found, downloading!")

        # Convert the path back into a list (without)
        # the filename -- we need to check that directories
        # exist first.
        path = os.path.split(dest)
        
        # Create any missing directories in dest(ination) path
        # -- os.path.join is the reverse of split (as you saw above)
        # but it doesn't work with lists... so I had to google how
        # to use the 'splat' operator! os.makedirs creates missing
        # directories in a path automatically.
        if len(path) >= 1 and path[0] != '':
            os.makedirs(os.path.join(*path), exist_ok=True)
            
        # Download and write the file
        with open(dfn, "wb") as file:
            response = get(src)
            file.write(response.content)
            
        print('Done downloading...')

    else:
        print(f"Found {dfn} locally!")

    return dfn

# %% [markdown]
# ### Cleaning the Data

# %%
evictions2019 = pd.read_excel('2019mortgage-landlord-possession-actions.xls', skiprows=[0,1,2], sheet_name = 'Table',header=[1])
evictions2022 = pd.read_excel('2022mortgage-landlord-possession-actions.xls', skiprows=[0,1,2], sheet_name = 'Table',header=[1])

# %%
evictions2019.head(10)
# Out:
#                    Area  Claims  Warrants  Repossessions  Outright Orders  \
# 0  Barking and Dagenham     129       100             12            48.00
# 1                Barnet     180       118             10            81.00
# 2                Bexley     146       101             20            52.00
# 3                 Brent     128        97              8            52.00
# 4               Bromley     151        81             13            42.00
# 5                Camden      62        31              6            23.00
# 6        City of London       3         2              2              NaN
# 7               Croydon     293       226             48           108.00
# 8                Ealing     145        92             17            53.00
# 9               Enfield     194       118             22            65.00
#
#    Suspended Orders
# 0             34.00
# 1             25.00
# 2             61.00
# 3             39.00
# 4             36.00
# 5              5.00
# ...

# %% [markdown]
# Here, there are several fields. Claims, warrants, outright orders, and suspended orders
# all represent steps in the process of evicting tenants. However, the "reposessions" field represents
# the actual displacement that takes place.

# %%
evictions2019.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Area              33 non-null     object
#  1   Claims            33 non-null     int64
#  2   Warrants          33 non-null     int64
#  3   Repossessions     33 non-null     int64
#  4   Outright Orders   32 non-null     float64
#  5   Suspended Orders  32 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.7+ KB

# %%
evictions2022.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Area              33 non-null     object
#  1   Claims            33 non-null     int64
#  2   Warrants          32 non-null     float64
#  3   Repossessions     29 non-null     float64
#  4   Outright Orders   32 non-null     float64
#  5   Suspended Orders  32 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.7+ KB

# %%
#There seems to be no data for several boroughs in the 2022 data.

# %%
evictions2019 = evictions2019.drop(axis=1, columns=["Claims", "Warrants","Suspended Orders", "Outright Orders"])
evictions2022 = evictions2022.drop(axis=1, columns=["Claims", "Warrants","Suspended Orders", "Outright Orders"])

# %%
evictions2019.head(5)
# Out:
#                    Area  Repossessions
# 0  Barking and Dagenham             12
# 1                Barnet             10
# 2                Bexley             20
# 3                 Brent              8
# 4               Bromley             13

# %%
evictions2022.head(5)
# Out:
#                    Area  Repossessions
# 0  Barking and Dagenham           5.00
# 1                Barnet           2.00
# 2                Bexley           5.00
# 3                 Brent           7.00
# 4               Bromley           4.00

# %% [markdown]
# ### Adding Geography

# %%
# some shapefiles
spath = 'https://github.com/jreades/fsds/blob/master/data/src/' # source path
ddir  = os.path.join('data','geo') # destination directory
water = gpd.read_file( cache_data(spath+'Water.gpkg?raw=true', ddir) )
boros = gpd.read_file( cache_data(spath+'Boroughs.gpkg?raw=true', ddir) )
green = gpd.read_file( cache_data(spath+'Greenspace.gpkg?raw=true', ddir) )
# Out:
# Found data/geo/Water.gpkg locally!
# Found data/geo/Boroughs.gpkg locally!
# Found data/geo/Greenspace.gpkg locally!

# %%
boros.head(5)
# Out:
#                    NAME   GSS_CODE  HECTARES  NONLD_AREA ONS_INNER  \
# 0  Kingston upon Thames  E09000021  3,726.12        0.00         F
# 1               Croydon  E09000008  8,649.44        0.00         F
# 2               Bromley  E09000006 15,013.49        0.00         F
# 3              Hounslow  E09000018  5,658.54       60.76         F
# 4                Ealing  E09000009  5,554.43        0.00         F
#
#                                             geometry
# 0  MULTIPOLYGON (((516401.600 160201.800, 516407....
# 1  MULTIPOLYGON (((535009.200 159504.700, 535005....
# 2  MULTIPOLYGON (((540373.600 157530.400, 540361....
# 3  MULTIPOLYGON (((521975.800 178100.000, 521967....
# 4  MULTIPOLYGON (((510253.500 182881.600, 510249....

# %%
evict2019_geom = pd.merge(evictions2019, boros, how="right", left_on='Area', right_on='NAME')
evict2022_geom = pd.merge(evictions2022, boros, how="right", left_on='Area', right_on='NAME')

# %%
evict_sums2019 = evict2019_geom['Repossessions']
evict_sums2019.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
evict_sums2022 = evict2022_geom['Repossessions']
evict_sums2022.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
evict2019_geom.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           33 non-null     object
#  1   Repossessions  33 non-null     int64
#  2   NAME           33 non-null     object
#  3   GSS_CODE       33 non-null     object
#  4   HECTARES       33 non-null     float64
#  5   NONLD_AREA     33 non-null     float64
#  6   ONS_INNER      33 non-null     object
#  7   geometry       33 non-null     geometry
# dtypes: float64(2), geometry(1), int64(1), object(4)
# memory usage: 2.3+ KB

# %%
evict2019_geom = gpd.GeoDataFrame(data=evict2019_geom, geometry='geometry', crs='epsg:27700')
gpd.GeoSeries(evict2019_geom.geometry)
# Out:
# 0     MULTIPOLYGON (((516401.600 160201.800, 516407....
# 1     MULTIPOLYGON (((535009.200 159504.700, 535005....
# 2     MULTIPOLYGON (((540373.600 157530.400, 540361....
# 3     MULTIPOLYGON (((521975.800 178100.000, 521967....
# 4     MULTIPOLYGON (((510253.500 182881.600, 510249....
# 5     MULTIPOLYGON (((549893.900 181459.800, 549894....
# 6     MULTIPOLYGON (((510599.800 191689.500, 510615....
# 7     MULTIPOLYGON (((510599.800 191689.500, 510660....
# 8     MULTIPOLYGON (((525201.000 182512.600, 525181....
# 9     MULTIPOLYGON (((524579.900 198355.200, 524594....
# 10    MULTIPOLYGON (((530046.800 177893.400, 530048....
# 11    MULTIPOLYGON (((531335.600 180529.500, 531337....
# 12    MULTIPOLYGON (((536691.000 178958.600, 536691....
# 13    MULTIPOLYGON (((537238.700 178137.700, 537242....
# 14    MULTIPOLYGON (((547226.200 181299.300, 547320....
# 15    MULTIPOLYGON (((531023.500 200933.600, 531039....
# 16    MULTIPOLYGON (((539923.100 191863.100, 539928....
# ...

# %%
evict2022_geom = gpd.GeoDataFrame(data=evict2022_geom, geometry='geometry', crs='epsg:27700')
gpd.GeoSeries(evict2022_geom.geometry)
# Out:
# 0     MULTIPOLYGON (((516401.600 160201.800, 516407....
# 1     MULTIPOLYGON (((535009.200 159504.700, 535005....
# 2     MULTIPOLYGON (((540373.600 157530.400, 540361....
# 3     MULTIPOLYGON (((521975.800 178100.000, 521967....
# 4     MULTIPOLYGON (((510253.500 182881.600, 510249....
# 5     MULTIPOLYGON (((549893.900 181459.800, 549894....
# 6     MULTIPOLYGON (((510599.800 191689.500, 510615....
# 7     MULTIPOLYGON (((510599.800 191689.500, 510660....
# 8     MULTIPOLYGON (((525201.000 182512.600, 525181....
# 9     MULTIPOLYGON (((524579.900 198355.200, 524594....
# 10    MULTIPOLYGON (((530046.800 177893.400, 530048....
# 11    MULTIPOLYGON (((531335.600 180529.500, 531337....
# 12    MULTIPOLYGON (((536691.000 178958.600, 536691....
# 13    MULTIPOLYGON (((537238.700 178137.700, 537242....
# 14    MULTIPOLYGON (((547226.200 181299.300, 547320....
# 15    MULTIPOLYGON (((531023.500 200933.600, 531039....
# 16    MULTIPOLYGON (((539923.100 191863.100, 539928....
# ...

# %%
evict2019_geom = evict2019_geom.to_crs('epsg:27700')
evict2022_geom = evict2022_geom.to_crs('epsg:27700')

# %%
evict2019_geom['area'] = evict2019_geom.area

# %%
evict2022_geom['area'] = evict2022_geom.area

# %%
evict2019_geom['density'] =  (evict2019_geom['Repossessions'] / evict2019_geom['area'])*1e6
#1e6 converts to km sq not m sq

# %%
evict2022_geom['density'] =  (evict2022_geom['Repossessions'] / evict2022_geom['area'])*1e6
#1e6 converts to km sq not m sq

# %%
evict2019_geom.density.max()
evict2022_geom.density.max()
# Out:
# 0.24744619055554526

# %%
evict2019_geom.head(5)
# Out:
#                    Area  Repossessions                  NAME   GSS_CODE  \
# 0  Kingston upon Thames              4  Kingston upon Thames  E09000021
# 1               Croydon             48               Croydon  E09000008
# 2               Bromley             13               Bromley  E09000006
# 3              Hounslow             17              Hounslow  E09000018
# 4                Ealing             17                Ealing  E09000009
#
#    HECTARES  NONLD_AREA ONS_INNER  \
# 0  3,726.12        0.00         F
# 1  8,649.44        0.00         F
# 2 15,013.49        0.00         F
# 3  5,658.54       60.76         F
# 4  5,554.43        0.00         F
#
#                                             geometry           area  density
# 0  MULTIPOLYGON (((516401.600 160201.800, 516407....  37,261,177.97     0.11
# 1  MULTIPOLYGON (((535009.200 159504.700, 535005....  86,494,436.33     0.55
# 2  MULTIPOLYGON (((540373.600 157530.400, 540361.... 150,134,857.88     0.09
# ...

# %%
#Kernel Density based on Evictions 2019
from mpl_toolkits.axes_grid1 import make_axes_locatable
def setColorbar(ax, colormap, vmin, vmax):
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    sm = plt.cm.ScalarMappable(cmap=colormap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    # fake up the array of the scalar mappable. Urgh...
    sm._A = []
    return plt.colorbar(sm, cax=cax)

vmin=0
vmax=15
cmap='viridis'
f,ax=plt.subplots(figsize=(10,10))
evict2019_geom.plot(column='density', alpha=0.5,ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)
setColorbar(ax, cmap, vmin=vmin, vmax=vmax)

# %%
#Kernel Density based on Evictions 2022
vmin=0
vmax=5
cmap='viridis'
f,ax=plt.subplots(figsize=(10,10))
evict2022_geom.plot(column='density', alpha=0.5,ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)
setColorbar(ax, cmap, vmin=vmin, vmax=vmax)

# %% [markdown]
# ##### Other methods of Transformation

# %%
# from sklearn.preprocessing import power_transform
# evict2019_geom["transformed_evict"] = power_transform(evict2019_geom[["density"]], method='yeo-johnson')

# %%
# from sklearn.preprocessing import power_transform
# evict2022_geom["transformed_evict"] = power_transform(evict2022_geom[["density"]], method='yeo-johnson')

# %%
# Transform the "sum_evictions" column
mms.fit(evict2019_geom[["Repossessions"]])
evict2019_geom["Standardised Evictions"] = mms.transform(evict2019_geom[["Repossessions"]])

# %%
# Transform the "sum_evictions" column
mms.fit(evict2022_geom[["Repossessions"]])
evict2022_geom["Standardised Evictions"] = mms.transform(evict2022_geom[["Repossessions"]])

# %% [markdown]
# ### Mapping

# %%
#Map the Density of 2019 Evictions by Borough
evict2019_geom = evict2019_geom.set_geometry('geometry')
evict2019_geom.plot(column='Standardised Evictions', legend=True, figsize=(8,8));
plt.suptitle("Transformed Evictions 2019", fontsize=14, fontweight='bold');

# %%
#Map the Density of 2022 Evictions by Borough
evict2022_geom = evict2022_geom.set_geometry('geometry')
evict2022_geom.plot(column='Standardised Evictions', legend=True, figsize=(8,8));
plt.suptitle("Transformed Evictions 2022", fontsize=14, fontweight='bold');

# %% [markdown]
# The reason there are holes in the map is because, in the dataset, the reposession values are NaNs. What this means
# is that there is no data on the reposession for that borough

# %% [markdown]
# ### Saving the New Dataset as a CSV

# %%
evict2019_geom.to_csv('2019_evictions_geom')

# %%
evict2022_geom.to_csv('2022_evictions_geom')
